# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('NetFlix.csv')
df_0 = pd.read_csv('NetFlix.csv')

# %%
df_0
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df_0.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
df_0.notnull().sum()
# Out:
# show_id         7787
# type            7787
# title           7787
# director        5398
# cast            7069
# country         7280
# date_added      7777
# release_year    7787
# rating          7780
# duration        7787
# genres          7787
# description     7787
# dtype: int64

# %%
df_0 = df_0.dropna().reset_index(drop=True)

# %%
df_0.notnull().sum()
# Out:
# show_id         4808
# type            4808
# title           4808
# director        4808
# cast            4808
# country         4808
# date_added      4808
# release_year    4808
# rating          4808
# duration        4808
# genres          4808
# description     4808
# dtype: int64

# %%
df_0.head()
# Out:
#   show_id   type                                      title         director  \
# 0     s10  Movie                                       1920     Vikram Bhatt
# 1    s100  Movie                                 3 Heroines   Iman Brotoseno
# 2   s1000  Movie  Blue Mountain State: The Rise of Thadland     Lev L. Spiro
# 3   s1002  Movie                                  Blue Ruin  Jeremy Saulnier
# 4   s1003  Movie                                Blue Streak     Les Mayfield
#
#                                                 cast                 country  \
# 0  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...                   India
# 1  Reza Rahadian, Bunga Citra Lestari, Tara Basro...               Indonesia
# 2  Alan Ritchson, Darin Brooks, James Cade, Rob R...           United States
# 3  Macon Blair, Devin Ratray, Amy Hargreaves, Kev...   United States, France
# 4  Martin Lawrence, Luke Wilson, Peter Greene, Da...  Germany, United States
#
# ...

# %%
df_0
# Out:
#      show_id   type                                      title  \
# 0        s10  Movie                                       1920
# 1       s100  Movie                                 3 Heroines
# 2      s1000  Movie  Blue Mountain State: The Rise of Thadland
# 3      s1002  Movie                                  Blue Ruin
# 4      s1003  Movie                                Blue Streak
# ...      ...    ...                                        ...
# 4803    s991  Movie                            Blood Will Tell
# 4804    s994  Movie                                       Blow
# 4805    s997  Movie                  Blue Is the Warmest Color
# 4806    s998  Movie                               Blue Jasmine
# 4807    s999  Movie                                   Blue Jay
#
#                         director  \
# 0                   Vikram Bhatt
# 1                 Iman Brotoseno
# 2                   Lev L. Spiro
# 3                Jeremy Saulnier
# 4                   Les Mayfield
# ...

# %%
df_0.head(2)
# Out:
#   show_id   type       title        director  \
# 0     s10  Movie        1920    Vikram Bhatt
# 1    s100  Movie  3 Heroines  Iman Brotoseno
#
#                                                 cast    country date_added  \
# 0  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...      India  15-Dec-17
# 1  Reza Rahadian, Bunga Citra Lestari, Tara Basro...  Indonesia   5-Jan-19
#
#    release_year rating  duration  \
# 0          2008  TV-MA       143
# 1          2016  TV-PG       124
#
#                                            genres  \
# 0  Horror Movies, International Movies, Thrillers
# 1     Dramas, International Movies, Sports Movies
#
#                                          description
# 0  An architect and his wife move into a castle t...
# 1  Three Indonesian women break records by becomi...

# %%
df_0['country'].unique()
# Out:
# array(['India', 'Indonesia', 'United States', 'United States, France',
#        'Germany, United States', 'Canada',
#        'Denmark, Sweden, Israel, United States', 'United Kingdom',
#        'Spain', 'United States, Iceland', 'Colombia', 'Germany',
#        'United Arab Emirates, United Kingdom, India', 'New Zealand',
#        'Netherlands', 'Egypt', 'Philippines', 'United Kingdom, Russia',
#        'Denmark, France, Poland', 'Lebanon', 'Canada, United States',
#        'Brazil', 'Poland', 'Bulgaria, United States',
#        'India, United Kingdom', 'United States, Canada, Ireland',
#        'Canada, United Kingdom', 'Japan',
#        'United States, Israel, Italy, South Africa', 'France, Belgium',
#        'Hong Kong', 'Australia', 'Kenya', 'South Korea', 'France',
#        'Turkey', 'China', 'India, United States', 'Indonesia, Singapore',
#        'South Korea, Japan',
#        'Philippines, Canada, United Kingdom, United States',
# ...

# %% [markdown]
# ## Error handeling in invalid dates

# %%
df_0['date_added'] = pd.to_datetime(df_0['date_added'], format="%Y-%m-%d", errors='ignore')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1912\3402794531.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df_0['date_added'] = pd.to_datetime(df_0['date_added'], format="%Y-%m-%d", errors='ignore')

# %%
df_0.head(30)
# Out:
#    show_id     type                                      title  \
# 0      s10    Movie                                       1920
# 1     s100    Movie                                 3 Heroines
# 2    s1000    Movie  Blue Mountain State: The Rise of Thadland
# 3    s1002    Movie                                  Blue Ruin
# 4    s1003    Movie                                Blue Streak
# 5    s1004    Movie                             Blue Valentine
# 6    s1005    Movie                               BluffMaster!
# 7    s1009    Movie                     Bo Burnham: Make Happy
# 8     s101    Movie                                   3 Idiots
# 9    s1010    Movie                          Bo Burnham: what.
# 10   s1012    Movie        Bob Lazar: Area 51 & Flying Saucers
# 11   s1014    Movie                        Bob's Broken Sleigh
# 12   s1015    Movie                                 Bobbi Jene
# 13   s1016    Movie                      Bobbleheads The Movie
# ...

# %% [markdown]
# ## Basic inspections

# %%
df_0.shape
# Out:
# (4808, 12)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['country'].unique()[:20]
# Out:
# array(['Brazil', 'India', 'Indonesia', 'United States', 'United Kingdom',
#        'United States, France', 'Germany, United States', 'Canada',
#        'Japan', 'Thailand', nan, 'Denmark, Sweden, Israel, United States',
#        'Ireland, United Kingdom', 'Spain', 'United States, Iceland',
#        'Colombia', 'Germany',
#        'United Arab Emirates, United Kingdom, India', 'New Zealand',
#        'Netherlands'], dtype=object)
